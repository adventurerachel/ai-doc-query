# %%
import io
import zipfile
import requests
import frontmatter

# %%
url = 'https://codeload.github.com/debauchee/barrier-wiki/faq/zip/refs/heads/main'
resp = requests.get(url)

# %%
def read_repo_data(repo_owner, repo_name):
    """
    Download and parse all markdown files from a GitHub repository.
    
    Args:
        repo_owner: GitHub username or organization
        repo_name: Repository name
    
    Returns:
        List of dictionaries containing file content and metadata
    """
    prefix = 'https://codeload.github.com' 
    url = f'{prefix}/{repo_owner}/{repo_name}/zip/refs/heads/master'
    resp = requests.get(url)
    
    if resp.status_code != 200:
        raise Exception(f"Failed to download repository: {resp.status_code}")

    repository_data = []
    zf = zipfile.ZipFile(io.BytesIO(resp.content))
    
    for file_info in zf.infolist():
        filename = file_info.filename
        filename_lower = filename.lower()

        if not (filename_lower.endswith('.md') 
            or filename_lower.endswith('.mdx')):
            continue
    
        try:
            with zf.open(file_info) as f_in:
                content = f_in.read().decode('utf-8', errors='ignore')
                post = frontmatter.loads(content)
                data = post.to_dict()
                data['filename'] = filename
                repository_data.append(data)
        except Exception as e:
            print(f"Error processing {filename}: {e}")
            continue
    
    zf.close()
    return repository_data

# %%
barrier_docs = read_repo_data('debauchee', 'barrier-wiki')

# %%
print(f"barrier docs: {len(barrier_docs)}")
# Out:
# barrier docs: 10

# %%
def sliding_window(seq, size, step):
    if size <= 0 or step <= 0:
        raise ValueError("size and step must be positive")

    n = len(seq)
    result = []
    for i in range(0, n, step):
        chunk = seq[i:i+size]
        result.append({'start': i, 'chunk': chunk})
        if i + size >= n:
            break

    return result

# %%
barrier_chunks = []

for doc in barrier_docs:
    doc_copy = doc.copy()
    doc_content = doc_copy.pop('content')
    chunks = sliding_window(doc_content, 2000, 1000)
    for chunk in chunks:
        chunk.update(doc_copy)
    barrier_chunks.extend(chunks)

# %%
print(type(barrier_chunks[0]))
print(barrier_chunks[0].keys())
# Out:
# <class 'dict'>
# dict_keys(['start', 'chunk', 'filename'])

# %%
from pprint import pprint
pprint(barrier_chunks[0]['chunk'][:200])
# Out:
# ('## Adding Barrier to the Windows Firewall\n'
#  '\n'
#  'Screenshots captured by [l0o0](https://github.com/l0o0)\n'
#  '\n'
#  '![search windows '
#  'defender](https://user-images.githubusercontent.com/2743744/49057950-ca40bd00-f23c-')

# %%
import re
text = barrier_docs[6]['content']
paragraphs = re.split(r"\n\s*\n", text.strip())

# %%
import re

def split_markdown_by_level(text, level=2):
    """
    Split markdown text by a specific header level.

    :param text: Markdown text as a string
    :param level: Header level to split on
    :return: List of sections as strings
    """
    # This regex matches markdown headers
    #For level 2, it matches lines starting with "## "
    header_pattern = r'^(#{' + str(level) + r'} )(.+)$'
    pattern = re.compile(header_pattern, re.MULTILINE)

    # Split and keep the headers
    parts = pattern.split(text)

    sections = []
    for i in range(1, len(parts), 3):
        # We step by 3 because regex.split() with
        # capturing groups returns:
        # [before_match, group1, group2, after_match, ...]
        # here group1 is "## ", group2 is the header text
        header = parts[i] + parts[i+1] # "##" + "Title"
        header = header.strip()

        # Get the content after this header
        content = ""
        if i+2 < len(parts):
            content = parts[i+2].strip()

        if content:
            section = f'{header}\n\n{content}'
        else:
            section = header
        sections.append(section)

    return sections

# %%
barrier_chunks = []

for doc in barrier_docs:
    doc_copy = doc.copy()
    doc_content = doc_copy.pop('content')
    sections = split_markdown_by_level(doc_content, level=2)
    for section in sections:
        section_doc = doc_copy.copy()
        section_doc['section'] = section
        barrier_chunks.append(section_doc)

# %%
from minsearch import Index

barrier_index = Index(
    text_fields=["chunk", "title", "description", "filename"],
    keyword_fields=[]
)

barrier_index.fit(barrier_chunks)

# %%
print(barrier_chunks[0].keys())
# Out:
# dict_keys(['filename', 'section'])

# %%
barrier_faq = read_repo_data('debauchee', 'barrier-wiki')

# %%
from sentence_transformers import SentenceTransformer
embedding_model = SentenceTransformer('multi-qa-distilbert-cos-v1')
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Loading weights:   0%|          | 0/100 [00:00<?, ?it/s]

# %%
record = de_barrier_faq[2]
text = record['question'] + ' ' + record['content']
v_doc = embedding_model.encode(text)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 record = de_barrier_faq[2]
#       2 text = record['question'] + ' ' + record['content']
#       3 v_doc = embedding_model.encode(text)
#
# NameError: name 'de_barrier_faq' is not defined

# %%
query = 'How do I install barrier on Mac OS?'
v_query = embedding_model.encode(query)

# %%
query = 'How do I install barrier on Mac OS?'
results = index.search(query)

# %%
similarity = v_query.dot(v_doc)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 similarity = v_query.dot(v_doc)
#
# NameError: name 'v_doc' is not defined

# %%
from tqdm.auto import tqdm
from minsearch import VectorSearch
import numpy as np

barrier_embeddings = []

for d in tqdm(barrier_chunks):
    v = embedding_model.encode(d['section'])
    barrier_embeddings.append(v)

barrier_embeddings = np.array(barrier_embeddings)

barrier_vindex = VectorSearch()
barrier_vindex.fit(barrier_embeddings, barrier_chunks)
# Out:
#   0%|          | 0/37 [00:00<?, ?it/s]

# %%
def text_search(query):
    return barrier_index.search(query, num_results=5)

def vector_search(query):
    q = embedding_model.encode(query)
    return barrier_vindex.search(q, num_results=5)

def hybrid_search(query):
    text_results = text_search(query)
    vector_results = vector_search(query)

    # Combine and dedupe results
    seen_ids = set()
    combined_results = []

    for result in text_results + vector_results:
        if result['filename'] not in seen_ids:
            seen_ids.add(result['filename'])
            combined_results.append(result)

    return combined_results

# %%
pprint(text_search('How do I install barrier in Mac OS?'))
# Out:
# [{'filename': 'barrier-wiki-master/Troubleshooting.md',
#   'section': '## Document Conventions\n'
#              '\n'
#              '- Text in angle brackets `<text>` is input supplied by the user\n'
#              '- Text in _italics_ are user interface elements, items '
#              'on-screen, or filenames\n'
#              '- Text in a `monospaced font` are keyboard shortcuts, prompts, '
#              'commands, or command output'},
#  {'filename': 'barrier-wiki-master/Troubleshooting.md',
#   'section': '## Things to Check\n'
#              '\n'
#              '- [The Command Line](#command_line)\n'
#              '- [Processes Running](#processes_running)\n'
#              '- [Server Reachability](#server_reachability)\n'
#              '- [Server Listening](#server_listening)\n'
#              '- [Multiple Instances](#multiple_instances)\n'
#              '- [Fingerprint Trust](#fingerprint_trust)'},
#  {'filename': 'barrier-wiki-master/Troubleshooting.md',
#   'section': '## <a name="command_line">Command Line</a>\n'
#              '\n'
#              'Most of the tools used to troubleshoot in this guide are run '
#              'from a text-based command line. These are some possible steps to '
#              'get to the command line interface.\n'
#              '\n'
#              '__Note:__ None of the below commands should require elevated '
#              'access (`Administrator cmd.exe`, `sudo`, `su`, `doas`, or '
#              'equivalent) unless specified.\n'
#              '\n'
#              '### Windows Command Prompt\n'
#              '1. Press the `(⊞ Win) + R` to open the _Run_ dialog\n'
#              '2. In the _Open:_ textbox, type `cmd` and click _OK_\n'
#              '\n'
#              '### Windows PowerShell\n'
#              '1. Press the `(⊞ Win) + R` to open the _Run_ dialog\n'
#              '2. In the _Open:_ textbox, type `powershell` and click _OK_\n'
#              '\n'
#              '### MacOS Terminal.app\n'
#              '1. Press `(⌘ Cmd) + Space` to open _Spotlight_ search\n'
#              '2. Type `Terminal.app` and press `Enter`\n'
#              '\n'
#              '### Linux Virtual Terminal\n'
#              'There are many ways to open a terminal emulator in the GUI on '
#              'various linux distributions. If you do not know how to access a '
#              'terminal emulator (`xterm`, `konsole`, `gnome-terminal`, etc...) '
#              'the steps for accessing the console are fairly standard. Press '
#              '`Ctrl + Alt` and one of the Function keys (usually `F1` through '
#              '`F7`) to switch between back and forth between the GUI and '
#              'virtual terminals. \n'
#              '\n'
#              '[Back to Top](#top)'},
#  {'filename': 'barrier-wiki-master/Troubleshooting.md',
#   'section': '## <a name="fingerprint_trust">Fingerprint Trust</a>\n'
#              '\n'
#              'Barrier uses fingerprints to validate that a malicious server is '
#              'not trying to intercept a client connection. These fingerprints '
#              'may be automatically generated if _Auto Config_ is selected in '
#              'the client. If your client does not trust the fingerprint it '
#              'will refuse the connection.\n'
#              '\n'
#              'The _TrustedServers.txt_ file should contain the fingerprint '
#              'found in the _Local.txt_ file on the server.\n'
#              '\n'
#              '### View the server fingerprint in the GUI\n'
#              '- Open the main Barrier GUI window\n'
#              '- The _SSL Fingerprint:_ field in the _Server_ section shows the '
#              'current server fingerprint\n'
#              '\n'
#              '### View the fingerprints on Windows\n'
#              '- Open _File Explorer_\n'
#              '- In the _path bar_ enter '
#              '`%LocalAppData%\\Barrier\\SSL\\Fingerprints`\n'
#              '- Double-click either _Local.txt_ for the server fingerprints, '
#              'or _TrustedServers.txt_ to view the fingerprints trusted by the '
#              'client\n'
#              '\n'
#              '### View the fingerprints on MacOS\n'
#              '- To view the trusted fingerprints on the client use the '
#              '[more](https://en.wikipedia.org/wiki/More_(command)) command to '
#              'view the _TrustedServers.txt_ file:\n'
#              '```shell\n'
#              'more ~/Library/Application\\ '
#              'Support/barrier/SSL/Fingerprints/TrustedServers.txt\n'
#              '```\n'
#              '- To view the server fingerprint on the server use the `more` '
#              'command again:\n'
#              '```\n'
#              'more ~/Library/Application\\ '
#              'Support/barrier/SSL/Fingerprints/Local.txt\n'
#              '```\n'
#              '\n'
#              '### View the trusted fingerprints on Linux or Unix\n'
#              '- To view the trusted fingerprints on the client use the '
#              '[more](https://en.wikipedia.org/wiki/More_(command)) command to '
#              'view the _TrustedServers.txt_ file:\n'
#              '```shell\n'
#              'more ~/.local/share/barrier/SSL/Fingerprints/TrustedServers.txt\n'
#              '```\n'
#              '- To view the server fingerprint on the server use the `more` '
#              'command again:\n'
#              '```shell\n'
#              'more ~/.local/share/barrier/SSL/Fingerprints/Local.txt\n'
#              '```\n'
#              '\n'
#              'On Linux or Unix systems the barrier _TrustedServers.txt_ or '
#              '_Local.txt_ files may not always be in the same place depending '
#              'on your system configuration. If they are elsewhere, use the '
#              '[find](https://en.wikipedia.org/wiki/Find_(Unix)) command to '
#              'locate them.\n'
#              '```\n'
#              "find / -type f -name '*TrustedServers.txt' 2>/dev/null\n"
#              "find / -type f -name '*Local.txt' 2>/dev/null\n"
#              '```\n'
#              '__Note 1:__ These `find` commands may find other files with the '
#              'same names. Check that the path includes `barrier`\n'
#              '\n'
#              '__Note 2:__ The `2>/dev/null` is to hide _Permission denied_ '
#              'errors you would otherwise get from searching directories you do '
#              'not have permission for as a normal user\n'
#              '\n'
#              '__Steps to try if unsuccessful:__\n'
#              '- Try to copy & paste the contents of _Local.txt_ on the server '
#              'into the _TrustedServers.txt_ file manually\n'
#              '\n'
#              '[Back to Top](#top)'},
#  {'filename': 'barrier-wiki-master/Troubleshooting.md',
#   'section': '## <a name="multiple_instances">Multiple Instances</a>\n'
#              '\n'
#              'Multiple instances of the background services that Barrier uses '
#              '(`barriers` on the server, and `barrierc` on the client) can '
#              'cause issues. For example, if another `barriers` process is '
#              'running in the backround it will prevent the current process '
#              'from binding to port `24800` and you may see incorrect status in '
#              'the GUI.\n'
#              '\n'
#              '### Windows\n'
#              '- Press `Ctrl + Shift + Esc` to open the _Task Manager_\n'
#              '- Click on the _Details_ tab and click on the _Name_ header to '
#              'sort by name\n'
#              '- Make sure there is only one `barrier.exe` process if the GUI '
#              'is running\n'
#              '- Make sure there is only one `barriers.exe` and one '
#              '`barrierd.exe` process if the server is running\n'
#              '- Make sure there is only one `barrierc.exe` and one '
#              '`barrierd.exe` process if the client is running\n'
#              '\n'
#              '### Linux/Unix/MacOS\n'
#              '- Use `grep` and `ps` to find barrier processes\n'
#              '```shell\n'
#              'ps -ax -o user,pid,command | grep -i [b]arrier\n'
#              '```\n'
#              '- Make sure there is only one `barrier` process if the GUI is '
#              'running\n'
#              '- Make sure there is only one `barriers` process if the server '
#              'is running\n'
#              '- Make sure there is only one `barrierc` process if the client '
#              'is running\n'
#              '\n'
#              '__Note:__ The barrier command line arguments may make a single '
#              'command wrap on the terminal to more than one line\n'
#              '\n'
#              '__Steps to try if unsuccessful:__\n'
#              '- Try stopping all of the barrier processes (_End Task_ on '
#              'Windows, `kill <pid>` on Linux/Unix/MacOS) and relaunching the '
#              'program\n'
#              '- Try restarting the computer\n'
#              '\n'
#              '[Back to Top](#top)'}]

# %%
pprint(vector_search('How do I install barrier in Mac OS?'))
# Out:
# [{'filename': 'barrier-wiki-master/Building-on-macOS.md',
#   'section': '## Before You Start\n'
#              '\n'
#              'You should be at least moderately comfortable with Git, CMake, '
#              'and the command\n'
#              'line before relying on this method. It requires a good bit of '
#              'free hard drive \n'
#              'space due to the large amount of dependencies required for the '
#              'build (see below)\n'
#              'and is meant for programmers that want to help discover and fix '
#              'programming \n'
#              'errors. When in doubt go for [binaries](Home) instead!\n'
#              '\n'
#              '# How to Build Barrier.app on MacOS\n'
#              '\n'
#              '*as of May 2020*\n'
#              '\n'
#              '- Install Xcode from the App Store or download and install it \n'
#              'from the [Apple Developer '
#              'Website](https://developer.apple.com/download/more/?=xcode)\n'
#              '- Install either [MacPorts](https://www.macports.org/) or '
#              '[Homebrew](https://brew.sh/) \n'
#              'following the instructions on their websites\n'
#              '- Install dependencies with either MacPorts or Homebrew (see '
#              'below)\n'
#              '- Build either the `Debug` or the `Release` targets (see below)\n'
#              '\n'
#              '### Install dependencies with MacPorts\n'
#              '\n'
#              '  - Install packages for Qt5, OpenSSL, and PkgConfig\n'
#              '  ```\n'
#              '  sudo port install qt5 openssl pkgconfig\n'
#              '  ```\n'
#              '  \n'
#              '### Install dependencies with Homebrew\n'
#              '\n'
#              '  - Install packages for Qt5, OpenSSL, and pkgconfig\n'
#              '  ```\n'
#              '  brew install qt5 openssl pkg-config\n'
#              '  ```\n'
#              '  \n'
#              '### Clone the repository\n'
#              '\n'
#              '  ```\n'
#              '  git clone https://github.com/debauchee/barrier\n'
#              '  ```\n'
#              '  - Change directories into the cloned repository\n'
#              '  ```\n'
#              '  cd barrier\n'
#              '  ```\n'
#              ' \n'
#              '### Build the Debug target\n'
#              '  *The debug target produces un-stripped binaries that have '
#              'symbols that can be \n'
#              '  used for debugging.*\n'
#              '\n'
#              '  - Build the `Debug` target using the `clean_build.sh` script\n'
#              '  ```\n'
#              '  ./clean_build.sh\n'
#              '  ```\n'
#              '  \n'
#              '  By default the resulting binaries will be in `./build/bin` and '
#              'the \n'
#              '  application bundle (.app) will be in `./build/bundle`. The '
#              'debug target\n'
#              '  does not create a disk image (dmg).\n'
#              '\n'
#              '### Build the Release target\n'
#              '  *The release target produces smaller stripped binaries and '
#              'distributable disk image. \n'
#              '  This is probably what you want if you are a user.*\n'
#              '  \n'
#              '  - Build the `Release` target using the `clean_build.sh` script '
#              'with environment variables\n'
#              '  \n'
#              '  *This step assumes the use of a bourne-like shell (i.e. bash). '
#              'If using another shell like*\n'
#              '  `csh` *change the export command to use* `setenv` *instead*.\n'
#              '  ```\n'
#              '  export B_BUILD_TYPE=Release\n'
#              '  ./clean_build.sh\n'
#              '  ```\n'
#              '  \n'
#              '  By default the resulting binaries will be in `./build/bin` and '
#              'the \n'
#              '  application bundle (.app) will be in `./build/bundle`. The '
#              'release target\n'
#              '  also creates a disk image (dmg).\n'
#              '  \n'
#              '#### Notes\n'
#              '  \n'
#              '  A '
#              '[`build_env.sh`](https://github.com/debauchee/barrier/blob/b6a1b5742006157c3fe746288961a9d2827a3f26/clean_build.sh#L20)\n'
#              '  file can be created for persistent build environment variables '
#              '[without being tracked by '
#              'git](https://github.com/debauchee/barrier/blob/b6a1b5742006157c3fe746288961a9d2827a3f26/.gitignore#L1)'},
#  {'filename': 'barrier-wiki-master/Command-Line.md',
#   'section': "## <a name='macos'>MacOS</a>\n"
#              '\n'
#              'To use Barrier commands from the command line on MacOS you can '
#              'either change\n'
#              'directories to the folder they are located and run them using '
#              'the relative path\n'
#              '(i.e. `./barriers`) each time or add the '
#              '`Barrier.app/Contents/MacOS` directory \n'
#              'to your `$PATH`.\n'
#              '\n'
#              '```cmd\n'
#              'cd /Applications/Barrier.app/Contents/MacOS/\n'
#              '```\n'
#              '\n'
#              'To add the directory to `$PATH`:\n'
#              '```cmd\n'
#              'export PATH=/Applications/Barrier.app/Contents/MacOS/:$PATH\n'
#              '```\n'
#              '\n'
#              'The `$PATH` variable will only be set for the duration of the '
#              'current shell\n'
#              'session. To make the path persistent, add it as a new line in '
#              'the `/etc/paths`\n'
#              'file or set the `$PATH` variable in your `.profile` or `.bashrc` '
#              'file.\n'
#              '\n'
#              '<a href="#top">Back to top</a>\n'
#              '\n'
#              '---'},
#  {'filename': 'barrier-wiki-master/Home.md',
#   'section': '## Binary Downloads\n'
#              '\n'
#              '- '
#              '[Windows](https://github.com/debauchee/barrier/releases/download/v2.3.3/BarrierSetup-2.3.3-release.exe)\n'
#              '  The installer will automatically download and install the '
#              'Visual C++ Runtime\n'
#              '  if necessary.\n'
#              '- '
#              '[macOS](https://github.com/debauchee/barrier/releases/download/v2.3.3/Barrier-2.3.3-release.dmg)\n'
#              '- Linux, FreeBSD, and OpenBSD - see\n'
#              '  [here](https://repology.org/project/barrier/versions) for a '
#              'list of packages\n'
#              '  available in package repositories.'},
#  {'filename': 'barrier-wiki-master/Command-Line.md',
#   'section': '## <a name="linux">Linux/Unix</a>\n'
#              '\n'
#              'If Barrier has been installed using a package manager or '
#              'equivalent it should\n'
#              'already be in your `$PATH`.\n'
#              '\n'
#              'If installed using flatpak, you can run the command line client '
#              'like this:\n'
#              '```cmd\n'
#              'flatpak run --command=barrierc com.github.debauchee.barrier\n'
#              '```\n'
#              'And server like this:\n'
#              '```cmd\n'
#              'flatpak run --command=barriers com.github.debauchee.barrier\n'
#              '```\n'
#              '\n'
#              '<a href="#top">Back to top</a>\n'
#              '\n'
#              '---'},
#  {'filename': 'barrier-wiki-master/Building-on-Windows.md',
#   'section': "## What's next?\n"
#              '\n'
#              '### Local changes\n'
#              '\n'
#              'Feel free to make whatever changes you like to your local copy '
#              'of Barrier. Barrier is open-source and licensed under the GPL so '
#              'as long as you abide by the '
#              '[license](https://raw.githubusercontent.com/debauchee/barrier/master/LICENSE) '
#              "then you're completely fine. Have fun!\n"
#              '\n'
#              '### Submitting patches\n'
#              '\n'
#              "If you make a change to Barrier's source that you think would "
#              'benefit others, fork the project on GitHub and submit a pull '
#              'request. If we agree that the patch would improve Barrier for a '
#              'wide range of users then we may merge it. At this point it will '
#              'have become an "official" change and you\'ll be credited in the '
#              "commit log. Isn't open-source wonderful? :)"}]

# %%
pprint(hybrid_search('how do I install barrier in Linux?'))
# Out:
# [{'filename': 'barrier-wiki-master/Building-on-Linux.md',
#   'section': '## Binaries Built\n'
#              '\n'
#              '- `barrier` the GUI front-end and "main" program\n'
#              '- `barriers` the CLI server component\n'
#              '- `barrierc` the CLI client component\n'
#              '\n'
#              "**note**: these aren't the only things build at compile time, "
#              'but merely what the end-user is expected to use.'},
#  {'filename': 'barrier-wiki-master/Troubleshooting.md',
#   'section': '## <a name="command_line">Command Line</a>\n'
#              '\n'
#              'Most of the tools used to troubleshoot in this guide are run '
#              'from a text-based command line. These are some possible steps to '
#              'get to the command line interface.\n'
#              '\n'
#              '__Note:__ None of the below commands should require elevated '
#              'access (`Administrator cmd.exe`, `sudo`, `su`, `doas`, or '
#              'equivalent) unless specified.\n'
#              '\n'
#              '### Windows Command Prompt\n'
#              '1. Press the `(⊞ Win) + R` to open the _Run_ dialog\n'
#              '2. In the _Open:_ textbox, type `cmd` and click _OK_\n'
#              '\n'
#              '### Windows PowerShell\n'
#              '1. Press the `(⊞ Win) + R` to open the _Run_ dialog\n'
#              '2. In the _Open:_ textbox, type `powershell` and click _OK_\n'
#              '\n'
#              '### MacOS Terminal.app\n'
#              '1. Press `(⌘ Cmd) + Space` to open _Spotlight_ search\n'
#              '2. Type `Terminal.app` and press `Enter`\n'
#              '\n'
#              '### Linux Virtual Terminal\n'
#              'There are many ways to open a terminal emulator in the GUI on '
#              'various linux distributions. If you do not know how to access a '
#              'terminal emulator (`xterm`, `konsole`, `gnome-terminal`, etc...) '
#              'the steps for accessing the console are fairly standard. Press '
#              '`Ctrl + Alt` and one of the Function keys (usually `F1` through '
#              '`F7`) to switch between back and forth between the GUI and '
#              'virtual terminals. \n'
#              '\n'
#              '[Back to Top](#top)'},
#  {'filename': 'barrier-wiki-master/Command-Line.md',
#   'section': '## <a name="linux">Linux/Unix</a>\n'
#              '\n'
#              'If Barrier has been installed using a package manager or '
#              'equivalent it should\n'
#              'already be in your `$PATH`.\n'
#              '\n'
#              'If installed using flatpak, you can run the command line client '
#              'like this:\n'
#              '```cmd\n'
#              'flatpak run --command=barrierc com.github.debauchee.barrier\n'
#              '```\n'
#              'And server like this:\n'
#              '```cmd\n'
#              'flatpak run --command=barriers com.github.debauchee.barrier\n'
#              '```\n'
#              '\n'
#              '<a href="#top">Back to top</a>\n'
#              '\n'
#              '---'},
#  {'filename': 'barrier-wiki-master/Home.md',
#   'section': '## Binary Downloads\n'
#              '\n'
#              '- '
#              '[Windows](https://github.com/debauchee/barrier/releases/download/v2.3.3/BarrierSetup-2.3.3-release.exe)\n'
#              '  The installer will automatically download and install the '
#              'Visual C++ Runtime\n'
#              '  if necessary.\n'
#              '- '
#              '[macOS](https://github.com/debauchee/barrier/releases/download/v2.3.3/Barrier-2.3.3-release.dmg)\n'
#              '- Linux, FreeBSD, and OpenBSD - see\n'
#              '  [here](https://repology.org/project/barrier/versions) for a '
#              'list of packages\n'
#              '  available in package repositories.'},
#  {'filename': 'barrier-wiki-master/Building-on-Windows.md',
#   'section': "## What's next?\n"
#              '\n'
#              '### Local changes\n'
#              '\n'
#              'Feel free to make whatever changes you like to your local copy '
#              'of Barrier. Barrier is open-source and licensed under the GPL so '
#              'as long as you abide by the '
#              '[license](https://raw.githubusercontent.com/debauchee/barrier/master/LICENSE) '
#              "then you're completely fine. Have fun!\n"
#              '\n'
#              '### Submitting patches\n'
#              '\n'
#              "If you make a change to Barrier's source that you think would "
#              'benefit others, fork the project on GitHub and submit a pull '
#              'request. If we agree that the patch would improve Barrier for a '
#              'wide range of users then we may merge it. At this point it will '
#              'have become an "official" change and you\'ll be credited in the '
#              "commit log. Isn't open-source wonderful? :)"}]
